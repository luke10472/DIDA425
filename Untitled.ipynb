# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv("Energy_Production_Sources.csv",low_memory=False)
df.drop(index=0, inplace=True)

df
# Out:
#     Year       Coal Petroleum Natural\n Gas Other\n Gas  Nuclear  \
# 1   2013  1,581,115    27,164     1,124,836      12,853  789,016
# 2   2014  1,581,710    30,232     1,126,635      12,022  797,166
# 3   2015  1,352,398    28,249     1,334,668      13,117  797,178
# 4   2016  1,239,149    24,205     1,379,271      12,807  805,694
# 5   2017  1,205,835    21,390     1,297,703      12,469  804,950
# 6   2018  1,149,487    25,226     1,471,843      13,463  807,084
# 7   2019    964,957    18,341     1,588,533      12,591  809,409
# 8   2020    773,393    17,341     1,626,790      11,818  789,879
# 9   2021    897,999    19,173     1,579,190      11,397  779,645
# 10  2022    831,512    22,931     1,687,067      11,722  771,537
#
#    Hydro\n Conven-\n tional Hydro\n Pumped\n Storage Geothermal     Wind  \
# 1                   268,565                   -4,681     15,775  167,840
# 2                   259,367                   -6,174     15,877  181,655
# ...

# %%
#data cleaning for year 0, 3000, and the incomplete 2023
green = []
#plotting the data
plt.plot(df['Year'], df['Wind'], marker='.', linestyle='-',color='purple')
plt.xlabel('Year')
plt.ylabel('Number of Shark Attacks')
plt.title('Number of Shark Attacks Over Time in the US')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' contains the DataFrame with the data
# Extract the 'Year' and 'Wind' columns
years = df['Year']
wind = df['Wind']

# Create a line plot
plt.plot(years, wind, marker='o', linestyle='-')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Wind Production (MW)')
plt.title('Wind Production Over Time')

# Display the plot
plt.grid(True)
plt.show()
